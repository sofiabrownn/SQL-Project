# %%
import requests
#import json package to decode json 
import json
import pandas as pd
from bs4 import BeautifulSoup
import sqlalchemy
from sqlalchemy import create_engine

# %%
oauth_token = 'oauth_token'
headers = {'Authorization': f'Bearer {oauth_token}'}

# %%
# Retrieved from https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF
top50_id = '37i9dQZEVXbNG2KDcFcKOF'

# %%
top50_url = f'https://api.spotify.com/v1/playlists/{top50_id}'

# %%
api_request = requests.get(top50_url, headers=headers)

# %%
api_request
# Out:
# <Response [200]>

# %%
api_request.text
# Out:
# '{\n  "collaborative" : false,\n  "description" : "Your weekly update of the most played tracks right now - Global.",\n  "external_urls" : {\n    "spotify" : "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"\n  },\n  "followers" : {\n    "href" : null,\n    "total" : 1020864\n  },\n  "href" : "https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF",\n  "id" : "37i9dQZEVXbNG2KDcFcKOF",\n  "images" : [ {\n    "height" : null,\n    "url" : "https://charts-images.scdn.co/assets/locale_en/regional/weekly/region_global_large.jpg",\n    "width" : null\n  } ],\n  "name" : "Top Songs - Global",\n  "owner" : {\n    "display_name" : "Spotify",\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/user/spotify"\n    },\n    "href" : "https://api.spotify.com/v1/users/spotify",\n    "id" : "spotify",\n    "type" : "user",\n    "uri" : "spotify:user:spotify"\n  },\n  "primary_color" : null,\n  "public" : false,\n  "snapshot_id" : "NzI5MzM3MDg1LDAwMDAwMDAwMDAwMDAwMDAwMD
# ...

# %%
json.loads(api_request.text)
# Out:
# {'collaborative': False,
#  'description': 'Your weekly update of the most played tracks right now - Global.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'},
#  'followers': {'href': None, 'total': 1020864},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF',
#  'id': '37i9dQZEVXbNG2KDcFcKOF',
#  'images': [{'height': None,
#    'url': 'https://charts-images.scdn.co/assets/locale_en/regional/weekly/region_global_large.jpg',
#    'width': None}],
#  'name': 'Top Songs - Global',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'NzI5MzM3MDg1LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
# ...

# %%
api_response = json.loads(api_request.text)

# %%
type(api_response)
# Out:
# dict

# %%
api_response['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2023-02-10T09:38:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
# ...

# %%
playlist_track=api_response['tracks']

# %%
for track in playlist_track['items'][0:3]:
  print(track['track']['name'])
# Out:
# Flowers
# Kill Bill
# Shakira: Bzrp Music Sessions, Vol. 53

# %%
playlist_data={
    'song':[],
    'artist':[],
    'song_id':[],
    'release_date':[],
    'song_popularity':[]
}

for track in playlist_track['items'][0:50]:
  song=track['track']['name']
  playlist_data['song'].append(song)
  print(song)

  artist=track['track']['artists'][0]['name']
  playlist_data['artist'].append(artist)
  print(artist)

  song_id=track['track']['id']
  playlist_data['song_id'].append(song_id)
  print(song_id)

  release_date=pd.to_datetime(track['track']['album']['release_date'])
  playlist_data['release_date'].append(release_date)
  print(release_date)

  #release_date=track['track']['album']['release_date']
  #playlist_data['release_date'].append(release_date)
  #print(release_date)
  
  song_popularity=track['track']['popularity']
  playlist_data['song_popularity'].append(song_popularity)
  print(song_popularity)


  print('-'*75)
# Out:
# Flowers
# Miley Cyrus
# 0yLdNVWF3Srea0uzk55zFn
# 2023-01-13 00:00:00
# 100
# ---------------------------------------------------------------------------
# Kill Bill
# SZA
# 1Qrg8KqiBpW07V7PNxwwwL
# 2022-12-08 00:00:00
# 91
# ---------------------------------------------------------------------------
# Shakira: Bzrp Music Sessions, Vol. 53
# Bizarrap
# 4nrPB8O7Y7wsOCJdgXkthe
# 2023-01-11 00:00:00
# 96
# ---------------------------------------------------------------------------
# Unholy (feat. Kim Petras)
# Sam Smith
# 0NZPBYD5qbEWRs3PrGiRkT
# 2023-01-27 00:00:00
# 82
# ---------------------------------------------------------------------------
# Creepin' (with The Weeknd & 21 Savage)
# Metro Boomin
# 2dHHgzDwk4BJdRwy9uXhTO
# 2022-12-02 00:00:00
# 93
# ---------------------------------------------------------------------------
# As It Was
# Harry Styles
# 4Dvkj6JhhA12EX05fT7y2e
# 2022-05-20 00:00:00
# 88
# ---------------------------------------------------------------------------
# ...

# %%
type(playlist_data)
# Out:
# dict

# %%
df = pd.DataFrame(playlist_data)

# %%
# !pip install mysqlclient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 KB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.1.1-cp38-cp38-linux_x86_64.whl size=109200 sha256=99192103fd46eb1ca23075f3a0d4c77301bb7f821a8aa6356f2f5198caae0b39
#   Stored in directory: /root/.cache/pip/wheels/5b/e1/84/a6185eaec318899f59a32d393af7729a0719cd93695d71f9a1
# Successfully built mysqlclient
# ...

# %%
engine = create_engine('mysql+mysqldb://USERNAME:PASSWORD@AWS_ENDPOINT?charset=utf8')

# %%
df.to_sql('TopSongsGlobal', engine, if_exists='append', index=False)
